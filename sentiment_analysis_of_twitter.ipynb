# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
import re
from sklearn.model_selection import train_test_split

# %%
 dataset=pd.read_csv('Sentiment.csv')

# %%
dataset
# Out:
#           id               candidate  candidate_confidence relevant_yn  \
# 0          1  No candidate mentioned                1.0000         yes
# 1          2            Scott Walker                1.0000         yes
# 2          3  No candidate mentioned                1.0000         yes
# 3          4  No candidate mentioned                1.0000         yes
# 4          5            Donald Trump                1.0000         yes
# ...      ...                     ...                   ...         ...
# 13866  13867  No candidate mentioned                1.0000         yes
# 13867  13868           Mike Huckabee                0.9611         yes
# 13868  13869                Ted Cruz                1.0000         yes
# 13869  13870            Donald Trump                1.0000         yes
# 13870  13871                Ted Cruz                0.9242         yes
#
#        relevant_yn_confidence sentiment  sentiment_confidence  \
# 0                      1.0000   Neutral                0.6578
# 1                      1.0000  Positive                0.6333
# 2                      1.0000   Neutral                0.6629
# 3                      1.0000  Positive                1.0000
# 4                      1.0000  Positive                0.7045
# ...                       ...       ...                   ...
# 13866                  1.0000  Negative                0.7991
# 13867                  1.0000  Positive                0.7302
# 13868                  1.0000  Positive                0.8051
# 13869                  1.0000  Negative                1.0000
# 13870                  0.9614  Positive                0.9614
#
#                              subject_matter  subject_matter_confidence  \
# 0                         None of the above                     1.0000
# 1                         None of the above                     1.0000
# 2                         None of the above                     0.6629
# 3                         None of the above                     0.7039
# 4                         None of the above                     1.0000
# ...                                     ...                        ...
# 13866                              Abortion                     0.6014
# 13867                     None of the above                     0.9229
# 13868                     None of the above                     0.9647
# 13869  Women's Issues (not abortion though)                     0.9202
# 13870                     None of the above                     0.9242
#
#                candidate_gold  ... relevant_yn_gold retweet_count  \
# 0                         NaN  ...              NaN             5
# 1                         NaN  ...              NaN            26
# 2                         NaN  ...              NaN            27
# 3                         NaN  ...              NaN           138
# 4                         NaN  ...              NaN           156
# ...                       ...  ...              ...           ...
# 13866  No candidate mentioned  ...              yes             7
# 13867           Mike Huckabee  ...              yes             1
# 13868                Ted Cruz  ...              yes            67
# 13869            Donald Trump  ...              yes           149
# 13870                Ted Cruz  ...              yes            65
#
#           sentiment_gold                             subject_matter_gold  \
# 0                    NaN                                             NaN
# 1                    NaN                                             NaN
# 2                    NaN                                             NaN
# 3                    NaN                                             NaN
# 4                    NaN                                             NaN
# ...                  ...                                             ...
# 13866           Negative  Abortion\nWomen's Issues (not abortion though)
# 13867                NaN                                             NaN
# 13868  Positive\nNeutral                                             NaN
# 13869                NaN            Women's Issues (not abortion though)
# 13870           Positive                                             NaN
#
#                                                     text tweet_coord  \
# 0      RT @NancyLeeGrahn: How did everyone feel about...         NaN
# 1      RT @ScottWalker: Didn't catch the full #GOPdeb...         NaN
# 2      RT @TJMShow: No mention of Tamir Rice and the ...         NaN
# 3      RT @RobGeorge: That Carly Fiorina is trending ...         NaN
# 4      RT @DanScavino: #GOPDebate w/ @realDonaldTrump...         NaN
# ...                                                  ...         ...
# 13866  RT @cappy_yarbrough: Love to see men who will ...         NaN
# 13867  RT @georgehenryw: Who thought Huckabee exceede...         NaN
# 13868  RT @Lrihendry: #TedCruz As President, I will a...         NaN
# 13869  RT @JRehling: #GOPDebate Donald Trump says tha...         NaN
# 13870  RT @Lrihendry: #TedCruz headed into the Presid...         NaN
#
#                    tweet_created            tweet_id   tweet_location  \
# 0      2015-08-07 09:54:46 -0700  629697200650592256              NaN
# 1      2015-08-07 09:54:46 -0700  629697199560069120              NaN
# 2      2015-08-07 09:54:46 -0700  629697199312482304              NaN
# 3      2015-08-07 09:54:45 -0700  629697197118861312            Texas
# 4      2015-08-07 09:54:45 -0700  629697196967903232              NaN
# ...                          ...                 ...              ...
# 13866  2015-08-07 09:29:43 -0700  629690895479250944             Como
# 13867  2015-08-07 09:25:02 -0700  629689719056568320              USA
# 13868  2015-08-07 07:19:18 -0700  629658075784282112              NaN
# 13869  2015-08-07 09:54:04 -0700  629697023663546368              NaN
# 13870  2015-08-06 18:22:27 -0700  629462573641920512  San Antonio, TX
#
#                     user_timezone
# 0                           Quito
# 1                             NaN
# 2                             NaN
# 3      Central Time (US & Canada)
# 4                         Arizona
# ...                           ...
# 13866                         NaN
# 13867                         NaN
# 13868                         NaN
# 13869                         NaN
# 13870  Central Time (US & Canada)
#
# [13871 rows x 21 columns]

# %%
dataset=dataset[['text','sentiment']]
dataset
# Out:
#                                                     text sentiment
# 0      RT @NancyLeeGrahn: How did everyone feel about...   Neutral
# 1      RT @ScottWalker: Didn't catch the full #GOPdeb...  Positive
# 2      RT @TJMShow: No mention of Tamir Rice and the ...   Neutral
# 3      RT @RobGeorge: That Carly Fiorina is trending ...  Positive
# 4      RT @DanScavino: #GOPDebate w/ @realDonaldTrump...  Positive
# ...                                                  ...       ...
# 13866  RT @cappy_yarbrough: Love to see men who will ...  Negative
# 13867  RT @georgehenryw: Who thought Huckabee exceede...  Positive
# 13868  RT @Lrihendry: #TedCruz As President, I will a...  Positive
# 13869  RT @JRehling: #GOPDebate Donald Trump says tha...  Negative
# 13870  RT @Lrihendry: #TedCruz headed into the Presid...  Positive
#
# [13871 rows x 2 columns]

# %%
dataset=dataset[dataset['sentiment']!='Neutral']
dataset
# Out:
#                                                     text sentiment
# 1      RT @ScottWalker: Didn't catch the full #GOPdeb...  Positive
# 3      RT @RobGeorge: That Carly Fiorina is trending ...  Positive
# 4      RT @DanScavino: #GOPDebate w/ @realDonaldTrump...  Positive
# 5      RT @GregAbbott_TX: @TedCruz: "On my first day ...  Positive
# 6      RT @warriorwoman91: I liked her and was happy ...  Negative
# ...                                                  ...       ...
# 13866  RT @cappy_yarbrough: Love to see men who will ...  Negative
# 13867  RT @georgehenryw: Who thought Huckabee exceede...  Positive
# 13868  RT @Lrihendry: #TedCruz As President, I will a...  Positive
# 13869  RT @JRehling: #GOPDebate Donald Trump says tha...  Negative
# 13870  RT @Lrihendry: #TedCruz headed into the Presid...  Positive
#
# [10729 rows x 2 columns]

# %%
train,test=train_test_split(dataset,test_size=0.1)

# %%
 train
# Out:
#                                                     text sentiment
# 8730   RT @Desdemona4U: It was unfathomable that @meg...  Negative
# 10444  RT @SupermanHotMale: Dear friends, it may seem...  Negative
# 10450  They were lynching Black folks in "Jesus Name"...  Negative
# 5715   #GOPDebate Turns Spectacle and Leaves @realDon...  Negative
# 2716   In the @AP factcheck of the #GOPDebate Jeb Bus...  Negative
# ...                                                  ...       ...
# 1336   In the #GOPDebate, @megynkelly was asking cand...  Positive
# 8120   RT @RWSurferGirl: Trump has got it right, nobo...  Positive
# 7036   It's just hilarious watching the usual #GOP sh...  Negative
# 8025   RT @RWSurferGirl: Fox News is obviously trying...  Negative
# 5144   RT @MeganSmiles: You also left out the collaps...  Negative
#
# [9656 rows x 2 columns]

# %%
test
# Out:
#                                                     text sentiment
# 7530   Trump showed he didn't belong but did GOP a fa...  Negative
# 1514   RT @DaTechGuyblog: Advice to #GOP candidates i...  Negative
# 1484   Preview of Donald Trump tonight at the #GOPDeb...  Negative
# 7846   Some candidates exaggerated their records at l...  Negative
# 2460   RT @shannonrwatts: The #NRA promotes gag order...  Negative
# ...                                                  ...       ...
# 11235  RT @RWSurferGirl: Is it just me or does anyone...  Negative
# 7776   Great images. #GOPDebate #photography https://...  Positive
# 4281            Jeb Bush underperforms at the #GOPDebate  Negative
# 464    RT @Marmel: MY mother worked.\nTHEIR mothers w...  Negative
# 6897   RT @rodeodance: @ScottWalker Dodges Media At S...  Negative
#
# [1073 rows x 2 columns]

# %%
train['text'][9720]
# Out:
# 'RT @RWSurferGirl: It is very disappointing that Fox News is not conducting a "Fair &amp; Balanced" Debate. 🇺🇸 #GOPDebate  #GOPDebates'

# %%
pattern="(#\w+)|(RT\s@\w+:)|(http.*)|(@\w+)"

# %%
ps=PorterStemmer()
lemmatizer=WordNetLemmatizer()

# %%
def clean_text(data):
    tweets=[]
    sentiments=[]
    for index,row in data.iterrows():
        sentence=re.sub(pattern,'',row.text)
        words=[e.lower() for e in sentence.split()]
        words=[lemmatizer.lemmatize(word) for word in words if word not in stopwords.words('english')]
        words=' '.join(words)
        tweets.append(words)
        sentiments.append(row.sentiment)
    return tweets,sentiments

# %%
train_tweets,train_sentiments=clean_text(train)

# %%
final_data={'tweets':train_tweets,'sentiments':train_sentiments}

# %%
processed_data=pd.DataFrame(final_data)

# %%
processed_data
# Out:
#                                                  tweets sentiments
# 0     it was unfathomable that would ask wasserman-s...   Negative
# 1     dear friends, it may seem like this is fun to ...   Negative
# 2     they were lynching black folks in "jesus name"...   Negative
# 3                     turns spectacle and leaves on top   Negative
# 4     in the factcheck of the jeb bush appears to co...   Negative
# ...                                                 ...        ...
# 9651  in the , was asking candidates questions she t...   Positive
# 9652  trump has got it right, nobody would talk abou...   Positive
# 9653  it's just hilarious watching the usual shills ...   Negative
# 9654  fox news is obviously trying to influence the ...   Negative
# 9655  you also left out the collapse of her obvious ...   Negative
#
# [9656 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
processed_data['sentiments']=labelencoder.fit_transform(processed_data['sentiments'])

# %%
processed_data
# Out:
#                                                  tweets  sentiments
# 0     it was unfathomable that would ask wasserman-s...           0
# 1     dear friends, it may seem like this is fun to ...           0
# 2     they were lynching black folks in "jesus name"...           0
# 3                     turns spectacle and leaves on top           0
# 4     in the factcheck of the jeb bush appears to co...           0
# ...                                                 ...         ...
# 9651  in the , was asking candidates questions she t...           1
# 9652  trump has got it right, nobody would talk abou...           1
# 9653  it's just hilarious watching the usual shills ...           0
# 9654  fox news is obviously trying to influence the ...           0
# 9655  you also left out the collapse of her obvious ...           0
#
# [9656 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(ngram_range=(1,3))
cv.fit(processed_data['tweets'])
# Out:
# CountVectorizer(ngram_range=(1, 3))

# %%
X_train=cv.transform(processed_data['tweets'])
print(X_train.shape)
# Out:
# (9656, 120345)

# %%
target=processed_data['sentiments'].values
target
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.naive_bayes import MultinomialNB
classifier=MultinomialNB()

# %%
classifier.fit(X_train.toarray(),target)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 classifier.fit(X_train.toarray(),target)
#
# File ~\anaconda3\Lib\site-packages\scipy\sparse\_compressed.py:1051, in _cs_matrix.toarray(self, order, out)
#    1049 if out is None and order is None:
#    1050     order = self._swap('cf')[0]
# -> 1051 out = self._process_toarray_args(order, out)
#    1052 if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1053     raise ValueError('Output array must be C or F contiguous')
#
# File ~\anaconda3\Lib\site-packages\scipy\sparse\_base.py:1298, in spmatrix._process_toarray_args(self, order, out)
#    1296     return out
#    1297 else:
# -> 1298     return np.zeros(self.shape, dtype=self.dtype, order=order)
#
# MemoryError: Unable to allocate 8.66 GiB for an array with shape (9656, 120345) and data type int64

# %%
test_tweets,test_sentiments=clean_text(test)

# %%
data_test={'tweets':test_tweets,'sentiments':test_sentiments}
final_test_data=pd.DataFrame(data_test)

# %%
X_test=cv.transform(final_data['tweets'])

# %%
X_test.shape
# Out:
# (9656, 120345)

# %%
y_pred=classifier.predict(X_test.toarray())
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 y_pred=classifier.predict(X_test.toarray())
#
# File ~\anaconda3\Lib\site-packages\scipy\sparse\_compressed.py:1051, in _cs_matrix.toarray(self, order, out)
#    1049 if out is None and order is None:
#    1050     order = self._swap('cf')[0]
# -> 1051 out = self._process_toarray_args(order, out)
#    1052 if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1053     raise ValueError('Output array must be C or F contiguous')
#
# File ~\anaconda3\Lib\site-packages\scipy\sparse\_base.py:1298, in spmatrix._process_toarray_args(self, order, out)
#    1296     return out
#    1297 else:
# -> 1298     return np.zeros(self.shape, dtype=self.dtype, order=order)
#
# MemoryError: Unable to allocate 8.66 GiB for an array with shape (9656, 120345) and data type int64

# %%
final_test_data['sentiments']=labelencoder.fit_transform(final_test_data['sentiments'])

# %%
final_test_data
# Out:
#                                                  tweets  sentiments
# 0     trump showed he didn't belong but did gop a fa...           0
# 1     advice to candidates in order of how i think t...           0
# 2     preview of donald trump tonight at the (vine by )           0
# 3     some candidates exaggerated their records at l...           0
# 4     the promotes gag orders to block military comm...           0
# ...                                                 ...         ...
# 1068  is it just me or does anyone else want to punc...           0
# 1069                                      great images.           1
# 1070                      jeb bush underperforms at the           0
# 1071  my mother worked. their mothers worked. your m...           0
# 1072     dodges media at state fair, hours before first           0
#
# [1073 rows x 2 columns]

# %%
actual_values=final_test_data['sentiments'].values
actual_values
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_pred,actual_values))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 2
#       1 from sklearn.metrics import accuracy_score
# ----> 2 print(accuracy_score(y_pred,actual_values))
#
# NameError: name 'y_pred' is not defined

# %%
classifier.predict(X_test.toarray()[[0]])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 classifier.predict(X_test.toarray()[[0]])
#
# File ~\anaconda3\Lib\site-packages\scipy\sparse\_compressed.py:1051, in _cs_matrix.toarray(self, order, out)
#    1049 if out is None and order is None:
#    1050     order = self._swap('cf')[0]
# -> 1051 out = self._process_toarray_args(order, out)
#    1052 if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1053     raise ValueError('Output array must be C or F contiguous')
#
# File ~\anaconda3\Lib\site-packages\scipy\sparse\_base.py:1298, in spmatrix._process_toarray_args(self, order, out)
#    1296     return out
#    1297 else:
# -> 1298     return np.zeros(self.shape, dtype=self.dtype, order=order)
#
# MemoryError: Unable to allocate 8.66 GiB for an array with shape (9656, 120345) and data type int64
